# %%
import eli5
import numpy as np
import pandas as pd
import gensim
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import mean_squared_log_error
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor
from sklearn.pipeline import FeatureUnion
import codecs
from nltk.tokenize import word_tokenize
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.base import TransformerMixin
from sklearn.pipeline import FeatureUnion, make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge


# from keras.api._v2.keras import Model, Sequential
# from keras.api._v2.keras.layers import Dense

# %%
dataset = pd.read_csv('data/train.tsv', sep='\t', header=0)
dataset['category_name'] = dataset['category_name'].fillna('Other').astype(str)
dataset['brand_name'] = dataset['brand_name'].fillna('missing').astype(str)
dataset['shipping'] = dataset['shipping'].astype(str)  # makes this categorical
dataset['item_condition_id'] = dataset['item_condition_id'].astype(str)
dataset['item_description'] = dataset['item_description'].fillna('None')

X = dataset.loc[:, dataset.columns != 'price']
Y = np.log1p(dataset['price'])

# 80% training data, 20% test data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
X_train.head(10)
# Out:
#          train_id                                      name item_condition_id  \
# 604635     604635                                      Enzo                 3
# 496799     496799                               Black dress                 3
# 1035231   1035231                      2 items for Brittany                 1
# 628659     628659                               Texas budle                 2
# 261459     261459                      North face rain coat                 3
# 959361     959361                Michael kors crossbody bag                 3
# 199415     199415                      Cream studded wedges                 3
# 1460850   1460850                 Pink and gold trinket box                 3
# 568899     568899  True religion button shirt slimsize XXXL                 3
# 1365752   1365752        WD Scorpio Blue 1TB 2.5 hard drive                 3
#
#                                              category_name  \
# 604635                           Women/Shoes/Mules & Clogs
# 496799                           Women/Dresses/Full-Length
# 1035231  Electronics/Cell Phones & Accessories/Cables &...
# 628659                       Women/Tops & Blouses/T-Shirts
# 261459                      Women/Athletic Apparel/Jackets
# 959361        Women/Women's Handbags/Messenger & Crossbody
# 199415                                 Women/Shoes/Sandals
# 1460850                 Home/Home Décor/Home Décor Accents
# 568899                                   Men/Tops/T-shirts
# 1365752  Electronics/Computers & Tablets/Drives, Storag...
#
#                         brand_name shipping  \
# 604635                     missing        0
# 496799                     missing        1
# 1035231                    missing        0
# 628659                     missing        0
# 261459              The North Face        0
# 959361                Michael Kors        0
# 199415                     missing        0
# 1460850                    missing        0
# 568899   True Religion Brand Jeans        1
# 1365752            Western Digital        1
#
#                                           item_description
# 604635   Enzo Angiolini Mules/Clogs. Super Cute with so...
# 496799   Xl long black dress Solid under with lace over...
# 1035231  - Urban Decay Eyeshadow This has never been us...
# 628659                                Very cute!! No flaws
# 261459   Sea foam green rain coat Size 18 XL in youth I...
# 959361                       Used , the color is rose gold
# 199415   The brand is Hot Rated purchased at Buckle. I ...
# 1460850  5.75" tall and 4.5" wide. Heavy resin. The fel...
# 568899   Please remember the brand name usually run sma...
# 1365752  Used like new condition Can be used on PS4 (yo...

# %%
word2vec_model = gensim.models.KeyedVectors.load_word2vec_format('data/glove.6B.300d.w2vformat.txt')

# %%
class w2vTransformer(TransformerMixin):
    """
    Wrapper class for running word2vec into pipelines and FeatureUnions
    """
    def __init__(self,word2vec,**kwargs):
        self.word2vec=word2vec
        self.kwargs=kwargs
        self.dim = len(word2vec.index_to_key)
    def fit(self,x, y=None):
        return self

    def transform(self, X):
        return np.array([
        np.mean([self.word2vec[w] for w in words if w in self.word2vec] 
            or [np.zeros(self.dim)], axis=0)
       for words in X
])

# %%
# %%time

preprocessor = CountVectorizer().build_preprocessor()


def build_field_preprocessor(field):
    field_idx = list(X_train.columns).index(field)
    return lambda x: preprocessor(x[field_idx])  # this preprocesses like stripping accents, etc.


vectorizer = FeatureUnion([
    ('name', CountVectorizer(
        ngram_range=(1, 2),  # extract words and pairs of words
        max_features=50_000,
        preprocessor=build_field_preprocessor('name')
    )),
    ('category_name', CountVectorizer(
        token_pattern='.+',  # separate by space
        preprocessor=build_field_preprocessor('category_name')
    )),
    ('brand_name', CountVectorizer(
        token_pattern='.+',  # separate by space
        preprocessor=build_field_preprocessor('brand_name')
    )),
    ('shipping', CountVectorizer(
        token_pattern='\d+',  # decimal numbers
        preprocessor=build_field_preprocessor('shipping')
    )),
    ('item_condition_id', CountVectorizer(
        token_pattern='\d+',  # decimal numbers
        preprocessor=build_field_preprocessor('item_condition_id')
    )),
    ("w2v_class",w2vTransformer(word2vec_model))
], n_jobs=8)

X_train_transformed = vectorizer.fit_transform(X_train.values)
X_test_transformed = vectorizer.transform(X_test.values)  # don't fit to the test
# Out:
# CPU times: total: 33 s
# Wall time: 57.1 s

# %%
# %%time

def rmsle(y_pred, y_true):
    return np.sqrt(mean_squared_log_error(np.expm1(y_pred.clip(0)), np.expm1(y_true)))


ridge_model = make_pipeline(StandardScaler(with_mean=False),
                            Ridge(
                                solver='auto',
                                fit_intercept=True,
                                alpha=0.5,
                                max_iter=100,
                                tol=0.05,
                            ))
ridge_model.fit(X_train_transformed, Y_train.values)

y_pred_validation_ridge = ridge_model.predict(X_test_transformed)
ridge_error = rmsle(y_pred_validation_ridge, Y_test.values)
print(f'Validation RMSLE for ridge regression = {ridge_error:.5f}')
# Out:
# Validation RMSLE for ridge regression = 0.49133
# CPU times: total: 13 s
# Wall time: 13.2 s

# %%
eli5.show_weights(ridge_model, vec=vectorizer, top=100, feature_filter=lambda x: x != '<BIAS>')
# Out:
# F:\Desktop\Classes\cs4120-hw4\.venv\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [69], line 1
# ----> 1 eli5.show_weights(ridge_model, vec=vectorizer, top=100, feature_filter=lambda x: x != '<BIAS>')
#
# File F:\Desktop\Classes\cs4120-hw4\.venv\lib\site-packages\eli5\ipython.py:130, in show_weights(estimator, **kwargs)
#      29 """ Return an explanation of estimator parameters (weights)
#      30 as an IPython.display.HTML object. Use this function
#      31 to show classifier weights in IPython.
#    (...)
#     127
#     128 """
#     129 format_kwargs, explain_kwargs = _split_kwargs(kwargs)
# --> 130 expl = explain_weights(estimator, **explain_kwargs)
#     131 _set_html_kwargs_defaults(format_kwargs)
#     132 html = format_as_html(expl, **format_kwargs)
#
# File C:\Python310\lib\functools.py:889, in singledispatch.<locals>.wrapper(*args, **kw)
#     885 if not args:
#     886     raise TypeError(f'{funcname} requires at least '
#     887                     '1 positional argument')
# --> 889 return dispatch(args[0].__class__)(*args, **kw)
#
# File F:\Desktop\Classes\cs4120-hw4\.venv\lib\site-packages\eli5\sklearn\explain_weights.py:475, in explain_weights_pipeline(estimator, feature_names, **kwargs)
#     473 transform_pipeline = Pipeline(estimator.steps[:-1])
#     474 if 'vec' in kwargs:
# --> 475     feature_names = get_feature_names(feature_names, vec=kwargs.pop('vec'))
#     476 feature_names = transform_feature_names(transform_pipeline, feature_names)
#     477 out = explain_weights(last_estimator,
#     478                       feature_names=feature_names,
#     479                       **kwargs)
#
# File F:\Desktop\Classes\cs4120-hw4\.venv\lib\site-packages\eli5\sklearn\utils.py:84, in get_feature_names(clf, vec, bias_name, feature_names, num_features, estimator_feature_names)
#      82 if feature_names is None:
#      83     if vec and hasattr(vec, 'get_feature_names'):
# ---> 84         return FeatureNames(vec.get_feature_names(), bias_name=bias_name)
#      85     else:
#      86         if estimator_feature_names is None:
#
# File F:\Desktop\Classes\cs4120-hw4\.venv\lib\site-packages\sklearn\utils\deprecation.py:88, in deprecated._decorate_fun.<locals>.wrapped(*args, **kwargs)
#      85 @functools.wraps(fun)
#      86 def wrapped(*args, **kwargs):
#      87     warnings.warn(msg, category=FutureWarning)
# ---> 88     return fun(*args, **kwargs)
#
# File F:\Desktop\Classes\cs4120-hw4\.venv\lib\site-packages\sklearn\pipeline.py:1074, in FeatureUnion.get_feature_names(self)
#    1072 for name, trans, weight in self._iter():
#    1073     if not hasattr(trans, "get_feature_names"):
# -> 1074         raise AttributeError(
#    1075             "Transformer %s (type %s) does not provide get_feature_names."
#    1076             % (str(name), type(trans).__name__)
#    1077         )
#    1078     feature_names.extend([name + "__" + f for f in trans.get_feature_names()])
#    1079 return feature_names
#
# AttributeError: Transformer w2v_class (type w2vTransformer) does not provide get_feature_names.
